# %% [markdown]
# # Data analysis on student data

# %% [markdown]
# ## Import the required libraries

# %%
# Import Pandas
import pandas as pd

# Import numpy
import numpy as np

# Import matplotlib
import matplotlib.pyplot as plt

# Import seaborn
import seaborn as sns

# %% [markdown]
# ### Load The Data Set

# %%
# Read the data file we have in the folder
df_indian_startup_founders_dataset = pd.read_csv('indian_startup_founders.csv')

df_indian_startup_founders_dataset
# Out:
#       founder_id             gender  age education_level   alma_mater  \
# 0         F00001               Male   23      Bachelor’s          NaN
# 1         F00002  Prefer not to say   22      Bachelor’s        Other
# 2         F00003  Prefer not to say   28     High School        Other
# 3         F00004               Male   23        Master’s        Other
# 4         F00005               Male   28      Bachelor’s  IIT Roorkee
# ...          ...                ...  ...             ...          ...
# 12495     F12496  Prefer not to say   45        Master’s        Other
# 12496     F12497             Female   22             PhD        Other
# 12497     F12498               Male   25        Master’s        Other
# 12498     F12499  Prefer not to say   23      Bachelor’s    IIT Delhi
# 12499     F12500  Prefer not to say   29      Bachelor’s        Other
#
#          field_of_study  prior_work_experience is_first_generation startup_id  \
# ...

# %% [markdown]
# #### Data Overview

# %%
df_indian_startup_founders_dataset.head()
# Out:
#   founder_id             gender  age education_level   alma_mater  \
# 0     F00001               Male   23      Bachelor’s          NaN
# 1     F00002  Prefer not to say   22      Bachelor’s        Other
# 2     F00003  Prefer not to say   28     High School        Other
# 3     F00004               Male   23        Master’s        Other
# 4     F00005               Male   28      Bachelor’s  IIT Roorkee
#
#      field_of_study  prior_work_experience is_first_generation startup_id  \
# 0       Engineering                     24                  No     S00216
# 1       Engineering                     13                 Yes     S08268
# 2          Business                      1                 Yes     S07952
# 3  Computer Science                      5                 Yes     S00991
# 4          Business                     18                 Yes     S07446
#
#   industry_sector  ...        state funding_amount  funding_rounds  \
# ...

# %%
df_indian_startup_founders_dataset.shape
# Out:
# (12500, 21)

# %% [markdown]
# ***Interpretation***
#  - We have 12500 observations(rows)
#  - We have 21 attributes(columns)

# %%
df_indian_startup_founders_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12500 entries, 0 to 12499
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   founder_id             12500 non-null  object
#  1   gender                 12500 non-null  object
#  2   age                    12500 non-null  int64
#  3   education_level        12500 non-null  object
#  4   alma_mater             11264 non-null  object
#  5   field_of_study         12500 non-null  object
#  6   prior_work_experience  12500 non-null  int64
#  7   is_first_generation    12500 non-null  object
#  8   startup_id             12500 non-null  object
#  9   industry_sector        12500 non-null  object
#  10  city                   12500 non-null  object
#  11  state                  12500 non-null  object
#  12  funding_amount         12500 non-null  float64
#  13  funding_rounds         12500 non-null  int64
# ...

# %% [markdown]
# ***Interpretation***
#  - We have 7 numerical column and 14 categorical column
#  - Memory usage if 2.0+ mb that means we does not required extra resources
#  - After observing output we can say missing records are there in data

# %%
df_indian_startup_founders_dataset.isnull().sum()
# Out:
# founder_id                  0
# gender                      0
# age                         0
# education_level             0
# alma_mater               1236
# field_of_study              0
# prior_work_experience       0
# is_first_generation         0
# startup_id                  0
# industry_sector             0
# city                        0
# state                       0
# funding_amount              0
# funding_rounds              0
# jobs_created                0
# is_unicorn                  0
# investor_count              0
# has_female_investor         0
# founding_year               0
# mentorship_access           0
# policy_support              0
# dtype: int64

# %%
df_indian_startup_founders_dataset.dropna(inplace=True)

# %%
df_indian_startup_founders_dataset = df_indian_startup_founders_dataset.reset_index(drop=True)

# %%
df_indian_startup_founders_dataset.shape
# Out:
# (11264, 21)

# %%
df_indian_startup_founders_dataset
# Out:
#       founder_id             gender  age education_level   alma_mater  \
# 0         F00002  Prefer not to say   22      Bachelor’s        Other
# 1         F00003  Prefer not to say   28     High School        Other
# 2         F00004               Male   23        Master’s        Other
# 3         F00005               Male   28      Bachelor’s  IIT Roorkee
# 4         F00006               Male   29      Bachelor’s        Other
# ...          ...                ...  ...             ...          ...
# 11259     F12496  Prefer not to say   45        Master’s        Other
# 11260     F12497             Female   22             PhD        Other
# 11261     F12498               Male   25        Master’s        Other
# 11262     F12499  Prefer not to say   23      Bachelor’s    IIT Delhi
# 11263     F12500  Prefer not to say   29      Bachelor’s        Other
#
#          field_of_study  prior_work_experience is_first_generation startup_id  \
# ...

# %%
df_indian_startup_founders_dataset.describe().T
# Out:
#                          count          mean           std          min  \
# age                    11264.0  2.864533e+01  7.982190e+00    18.000000
# prior_work_experience  11264.0  7.105469e+00  8.229445e+00     0.000000
# funding_amount         11264.0  2.031366e+07  5.942883e+07  2629.241623
# funding_rounds         11264.0  4.308949e+00  2.846589e+00     0.000000
# jobs_created           11264.0  3.787075e+02  9.179381e+02     0.000000
# investor_count         11264.0  1.460742e+01  1.323575e+01     0.000000
# founding_year          11264.0  2.016044e+03  7.003012e+00  2000.000000
#
#                                  25%           50%           75%          max
# age                        24.000000  2.700000e+01  2.900000e+01         60.0
# prior_work_experience       2.000000  4.000000e+00  1.000000e+01         30.0
# funding_amount         815002.173461  3.193052e+06  1.215828e+07  500000000.0
# funding_rounds              2.000000  4.000000e+00  6.000000e+00         10.0
# ...

# %% [markdown]
# **Interpretation**
#  - We don't have outliers in data

# %% [markdown]
# # **UNIVARIATE ANALYSIS**

# %%
#Segragate the data

df_num=df_indian_startup_founders_dataset.select_dtypes(include='number')
df_cat=df_indian_startup_founders_dataset.select_dtypes(include='object')

# %%
df_num.columns
# Out:
# Index(['age', 'prior_work_experience', 'funding_amount', 'funding_rounds',
#        'jobs_created', 'investor_count', 'founding_year'],
#       dtype='object')

# %%
df_cat
# Out:
#       founder_id             gender education_level   alma_mater  \
# 0         F00002  Prefer not to say      Bachelor’s        Other
# 1         F00003  Prefer not to say     High School        Other
# 2         F00004               Male        Master’s        Other
# 3         F00005               Male      Bachelor’s  IIT Roorkee
# 4         F00006               Male      Bachelor’s        Other
# ...          ...                ...             ...          ...
# 11259     F12496  Prefer not to say        Master’s        Other
# 11260     F12497             Female             PhD        Other
# 11261     F12498               Male        Master’s        Other
# 11262     F12499  Prefer not to say      Bachelor’s    IIT Delhi
# 11263     F12500  Prefer not to say      Bachelor’s        Other
#
#          field_of_study is_first_generation startup_id     industry_sector  \
# 0           Engineering                 Yes     S08268            Software
# ...

# %%
df_cat.columns
# Out:
# Index(['founder_id', 'gender', 'education_level', 'alma_mater',
#        'field_of_study', 'is_first_generation', 'startup_id',
#        'industry_sector', 'city', 'state', 'is_unicorn', 'has_female_investor',
#        'mentorship_access', 'policy_support'],
#       dtype='object')

# %% [markdown]
# ## Perform univariate Analysis on Numerical Columns

# %%
df_num.columns
# Out:
# Index(['age', 'prior_work_experience', 'funding_amount', 'funding_rounds',
#        'jobs_created', 'investor_count', 'founding_year'],
#       dtype='object')

# %% [markdown]
# ### age

# %%
#show the min
df_num.age.min()
# Out:
# 18

# %%
#show the max
df_num.age.max()
# Out:
# 60

# %%
#show the mean
df_num.age.mean().round(3)
# Out:
# 28.645

# %%
#plot the graph
df_num.age.plot(kind='kde' ,color='blue')
plt.title('age distribution')
plt.xlabel('age')
plt.grid()
plt.show()

# %% [markdown]
#   **Interpretation**
#  - The minimum age of employee is 18.
#  - The maximum age of employee is 60.
#  - The average age of employee is 28.645.

# %%
df_num.columns
# Out:
# Index(['age', 'prior_work_experience', 'funding_amount', 'funding_rounds',
#        'jobs_created', 'investor_count', 'founding_year'],
#       dtype='object')

# %% [markdown]
# ### prior_work_experience

# %%
#show the min
df_num.prior_work_experience.min()
# Out:
# 0

# %%
#show the max
df_num.prior_work_experience.max()
# Out:
# 30

# %%
#show the mean
df_num.prior_work_experience.mean().round(3)
# Out:
# 7.105

# %%
#plot the graph
df_num.prior_work_experience.plot(kind='kde' ,color='blue')
plt.title('prior_work_experience distribution')
plt.xlabel('prior_work_experience')
plt.grid()
plt.show()

# %%
df_num.columns
# Out:
# Index(['age', 'prior_work_experience', 'funding_amount', 'funding_rounds',
#        'jobs_created', 'investor_count', 'founding_year'],
#       dtype='object')

# %% [markdown]
# ### funding_amount

# %%
#show the min
df_num.funding_amount.min()
# Out:
# 2629.2416231964703

# %%
#show the max
df_num.funding_amount.max()
# Out:
# 500000000.0

# %%
#show the mean
df_num.funding_amount.mean().round(3)
# Out:
# 20313655.879

# %%
#plot the graph
df_num.funding_amount.plot(kind='kde' ,color='blue')
plt.title('funding_amount distribution')
plt.xlabel('funding_amount')
plt.grid()
plt.show()

# %% [markdown]
#   **Interpretation**
#  - The minimum Funding amount is 2629.2416231964703.
#  - The maximum Funding amount is 500000000.0.
#  - The average funding amount is 20313655.879.

# %%
df_num.columns
# Out:
# Index(['age', 'prior_work_experience', 'funding_amount', 'funding_rounds',
#        'jobs_created', 'investor_count', 'founding_year'],
#       dtype='object')

# %% [markdown]
# ### funding_rounds

# %%
#show the min
df_num.funding_rounds.min()
# Out:
# 0

# %%
#show the max
df_num.funding_rounds.max()
# Out:
# 10

# %%
#show the mean
df_num.funding_rounds.mean().round(3)
# Out:
# 4.309

# %%
#plot the graph
df_num.funding_rounds.plot(kind='kde' ,color='blue')
plt.title('funding_rounds distribution')
plt.xlabel('funding_rounds')
plt.grid()
plt.show()

# %% [markdown]
#   **Interpretation**
#  - The minimum Funding Rounds is 0.
#  - The maximum Funding Rounds is 10.
#  - The average Funding Rounds is 4.309.

# %%
df_num.columns
# Out:
# Index(['age', 'prior_work_experience', 'funding_amount', 'funding_rounds',
#        'jobs_created', 'investor_count', 'founding_year'],
#       dtype='object')

# %% [markdown]
# ### jobs_created

# %%
# show the min
df_num.jobs_created.min()
# Out:
# 0

# %%
# show the max
df_num.jobs_created.max()
# Out:
# 4997

# %%
#show the mean
df_num.jobs_created.mean().round(3)
# Out:
# 378.707

# %%
#plot the graph
df_num.jobs_created.plot(kind='kde' ,color='blue')
plt.title('jobs_created distribution')
plt.xlabel('jobs_created')
plt.grid()
plt.show()

# %% [markdown]
#   **Interpretation**
#  - The minimum Jobs created is 0.
#  - The maximum Jobs createde is 4997.
#  - The average Jobs created is 378.707.

# %%
df_num.columns
# Out:
# Index(['age', 'prior_work_experience', 'funding_amount', 'funding_rounds',
#        'jobs_created', 'investor_count', 'founding_year'],
#       dtype='object')

# %% [markdown]
# ### investor_count

# %%
# show the min
df_num.investor_count.min()
# Out:
# 0

# %%
#show the max
df_num.investor_count.max()
# Out:
# 50

# %%
#show the mean
df_num.investor_count.mean().round(3)
# Out:
# 14.607

# %%
#plot the graph
df_num.investor_count.plot(kind='kde' ,color='blue')
plt.title('investor_count distribution')
plt.xlabel('investor_count')
plt.grid()
plt.show()

# %% [markdown]
#   **Interpretation**
#  - The minimum Investor Count is 0.
#  - The maximum Investor Count is 50.
#  - The average of Investor Count is 14.607.

# %%
df_num.columns
# Out:
# Index(['age', 'prior_work_experience', 'funding_amount', 'funding_rounds',
#        'jobs_created', 'investor_count', 'founding_year'],
#       dtype='object')

# %% [markdown]
# ### founding_year

# %%
#show the min
df_num.founding_year.min()
# Out:
# 2000

# %%
#show the max
df_num.founding_year.max()
# Out:
# 2025

# %%
#show the mean
df_num.founding_year.mean().round(3)
# Out:
# 2016.044

# %%
#plot the graph
df_num.founding_year.plot(kind='kde' ,color='blue')
plt.title('founding_year distribution')
plt.xlabel('founding_year')
plt.grid()
plt.show()

# %% [markdown]
#   **Interpretation**
#  - The minimum Founding Year is 2000.
#  - The maximum Founding Year is 2025.
#  - The average Founding Year is 2016.044.

# %% [markdown]
# ## Univariate Analysis on Categorical Columns

# %%
df_cat.columns
# Out:
# Index(['founder_id', 'gender', 'education_level', 'alma_mater',
#        'field_of_study', 'is_first_generation', 'startup_id',
#        'industry_sector', 'city', 'state', 'is_unicorn', 'has_female_investor',
#        'mentorship_access', 'policy_support'],
#       dtype='object')

# %% [markdown]
# ### founder_id

# %%
#show the count
df_cat.founder_id.value_counts()
# Out:
# founder_id
# F00002    1
# F00003    1
# F08328    1
# F08329    1
# F08330    1
#          ..
# F04160    1
# F04161    1
# F04163    1
# F04164    1
# F12500    1
# Name: count, Length: 11264, dtype: int64

# %%
#due to large categories we are dropping this column
df_cat=df_cat.drop('founder_id',axis=1)

# %%
df_cat.columns
# Out:
# Index(['gender', 'education_level', 'alma_mater', 'field_of_study',
#        'is_first_generation', 'startup_id', 'industry_sector', 'city', 'state',
#        'is_unicorn', 'has_female_investor', 'mentorship_access',
#        'policy_support'],
#       dtype='object')

# %% [markdown]
# ### gender

# %%
#show the counts
df_cat.gender.value_counts()
# Out:
# gender
# Male                 6835
# Prefer not to say    3076
# Female               1123
# Non-binary            230
# Name: count, dtype: int64

# %%
#plot the graph
df_cat.gender.value_counts().plot(kind='bar',color='blue')
plt.title('Gender Count')
plt.xlabel('Gender')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The number of Male employee is 6835.
#  - The number of employee whose gender is not defined is 3076.
#  - The number of Female employee is 1123.
#  - The number of non binary employee is 230.

# %%
df_cat.columns
# Out:
# Index(['gender', 'education_level', 'alma_mater', 'field_of_study',
#        'is_first_generation', 'startup_id', 'industry_sector', 'city', 'state',
#        'is_unicorn', 'has_female_investor', 'mentorship_access',
#        'policy_support'],
#       dtype='object')

# %% [markdown]
# ### education_level

# %%
# show the counts
df_cat.education_level.value_counts()
# Out:
# education_level
# Bachelor’s     6799
# Master’s       2739
# PhD             604
# Other           577
# High School     545
# Name: count, dtype: int64

# %%
# plot the graph
df_cat.education_level.value_counts().plot(kind='bar',color='blue')
plt.title('education_level Count')
plt.xlabel('education_level')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The number of Employee done their Bachelor's is 6799.
#  - The number of Employee done their Master's is 2739.
#  - The number of Employee done their PHD is 604.
#  - The number of Employee done Other Study is 577.
#  - The number of Employee done their High School Study is 545.

# %%
df_cat.columns
# Out:
# Index(['gender', 'education_level', 'alma_mater', 'field_of_study',
#        'is_first_generation', 'startup_id', 'industry_sector', 'city', 'state',
#        'is_unicorn', 'has_female_investor', 'mentorship_access',
#        'policy_support'],
#       dtype='object')

# %% [markdown]
# ### alma_mater

# %%
# show the count
df_cat.alma_mater.value_counts()
# Out:
# alma_mater
# Other          7605
# BITS Pilani    1432
# IIT Delhi      1228
# IIT Roorkee     999
# Name: count, dtype: int64

# %%
# plot the graph
df_cat.alma_mater.value_counts().plot(kind='bar',color='blue')
plt.title('alma_mater Count')
plt.xlabel('alma_mater')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The number of employee studied from other college is 7605.
#  - The number of employee studied from BITS Pilani is 1432.
#  - The number of employee studied from IIT Delhi is 1228.
#  - The number of employee studied from IIT Roorkee is 999.

# %%
df_cat.columns
# Out:
# Index(['gender', 'education_level', 'alma_mater', 'field_of_study',
#        'is_first_generation', 'startup_id', 'industry_sector', 'city', 'state',
#        'is_unicorn', 'has_female_investor', 'mentorship_access',
#        'policy_support'],
#       dtype='object')

# %% [markdown]
# ### field_of_study

# %%
# show the counts
df_cat.field_of_study.value_counts()
# Out:
# field_of_study
# Computer Science    3397
# Engineering         2816
# Business            2164
# Other               1736
# Arts                1151
# Name: count, dtype: int64

# %%
# plot the graph
df_cat.field_of_study.value_counts().plot(kind='bar',color='blue')
plt.title('field_of_study Count')
plt.xlabel('field_of_study')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The number of employee studied from Computer Science is 3397.
#  - The number of employee studied from Engineering is 2816.
#  - The number of employee studied from Business is 2164.
#  - The number of employee studied from Other Branch is 1736.
#  - The number of employee studied from Arts is 1151.

# %%
df_cat.columns
# Out:
# Index(['gender', 'education_level', 'alma_mater', 'field_of_study',
#        'is_first_generation', 'startup_id', 'industry_sector', 'city', 'state',
#        'is_unicorn', 'has_female_investor', 'mentorship_access',
#        'policy_support'],
#       dtype='object')

# %% [markdown]
# ### is_first_generation

# %%
# show the counts
df_cat.is_first_generation.value_counts()
# Out:
# is_first_generation
# Yes    9040
# No     2224
# Name: count, dtype: int64

# %%
# plot the graph
df_cat.is_first_generation.value_counts().plot(kind='bar',color='blue')
plt.title('is_first_generation Count')
plt.xlabel('is_first_generation')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The number of Founder from first generation is 9040.
#  - The number of Founder which are not from first generation is 2224.

# %%
df_cat.columns
# Out:
# Index(['gender', 'education_level', 'alma_mater', 'field_of_study',
#        'is_first_generation', 'startup_id', 'industry_sector', 'city', 'state',
#        'is_unicorn', 'has_female_investor', 'mentorship_access',
#        'policy_support'],
#       dtype='object')

# %% [markdown]
# ### startup_id

# %%
# show the counts
df_cat.startup_id.value_counts()
# Out:
# startup_id
# S04335    8
# S04712    7
# S05265    7
# S00141    7
# S00403    7
#          ..
# S06379    1
# S07108    1
# S06403    1
# S02227    1
# S01856    1
# Name: count, Length: 6129, dtype: int64

# %%
#due to large categories we are dropping this column
df_cat=df_cat.drop('startup_id',axis=1)

# %%
df_cat.columns
# Out:
# Index(['gender', 'education_level', 'alma_mater', 'field_of_study',
#        'is_first_generation', 'industry_sector', 'city', 'state', 'is_unicorn',
#        'has_female_investor', 'mentorship_access', 'policy_support'],
#       dtype='object')

# %% [markdown]
# ### industry_sector

# %%
# show the counts
df_cat.industry_sector.value_counts()
# Out:
# industry_sector
# Software              3307
# Other                 2832
# Consumer Goods        2222
# Financial Services    1773
# Healthcare            1130
# Name: count, dtype: int64

# %%
# plot the graph
df_cat.industry_sector.value_counts().plot(kind='bar',color='blue')
plt.title('industry_sector Count')
plt.xlabel('industry_sector')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The number of employee from Softwear sector is 3307.
#  - The number of employee from other sector is 2832.
#  - The number of employee from Consumer Goods sector is 2222.
#  - The number of employee from Financial Services sector is 1773.
#  - The number of employee from Healthcare sector is 1130.

# %%
df_cat.columns
# Out:
# Index(['gender', 'education_level', 'alma_mater', 'field_of_study',
#        'is_first_generation', 'industry_sector', 'city', 'state', 'is_unicorn',
#        'has_female_investor', 'mentorship_access', 'policy_support'],
#       dtype='object')

# %% [markdown]
# ### city

# %%
# show the count
df_cat.city.value_counts()
# Out:
# city
# Other        3946
# Mumbai       2922
# Bengaluru    2284
# Gurugram     1093
# Delhi        1019
# Name: count, dtype: int64

# %%
# plot the graph
df_cat.city.value_counts().plot(kind='bar',color='blue')
plt.title('city Count')
plt.xlabel('city')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The number of employee from other city is 3946.
#  - The number of employee from Mumbai is 2922.
#  - The number of employee from Bengaluru is 2284.
#  - The number of employee from Gurugram is 1093.
#  - The number of employee from Delhi is 1019.

# %%
df_cat.columns
# Out:
# Index(['gender', 'education_level', 'alma_mater', 'field_of_study',
#        'is_first_generation', 'industry_sector', 'city', 'state', 'is_unicorn',
#        'has_female_investor', 'mentorship_access', 'policy_support'],
#       dtype='object')

# %% [markdown]
# ### state

# %%
# show the counts
df_cat.state.value_counts()
# Out:
# state
# Other          5018
# Maharashtra    2794
# Karnataka      2272
# Delhi          1180
# Name: count, dtype: int64

# %%
# plot the graph
df_cat.state.value_counts().plot(kind='bar',color='blue')
plt.title('state Count')
plt.xlabel('state')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The number of employee from other state is 5018.
#  - The number of employee from Maharashtra is 2794.
#  - The number of employee from Karnataka is 2272.
#  - The number of employee from Delhi is 1180.

# %%
df_cat.columns
# Out:
# Index(['gender', 'education_level', 'alma_mater', 'field_of_study',
#        'is_first_generation', 'industry_sector', 'city', 'state', 'is_unicorn',
#        'has_female_investor', 'mentorship_access', 'policy_support'],
#       dtype='object')

# %% [markdown]
# ### is_unicorn

# %%
# show the counts
df_cat.is_unicorn.value_counts()
# Out:
# is_unicorn
# No     10282
# Yes      982
# Name: count, dtype: int64

# %%
# plot the graph
df_cat.is_unicorn.value_counts().plot(kind='bar',color='blue')
plt.title('is_unicorn Count')
plt.xlabel('is_unicorn')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The number of startup which are unicorn is 982.
#  - The number of startup which are not unicorn is 10282.

# %%
df_cat.columns
# Out:
# Index(['gender', 'education_level', 'alma_mater', 'field_of_study',
#        'is_first_generation', 'industry_sector', 'city', 'state', 'is_unicorn',
#        'has_female_investor', 'mentorship_access', 'policy_support'],
#       dtype='object')

# %% [markdown]
# ### has_female_investor

# %%
# show the counts
df_cat.has_female_investor.value_counts()
# Out:
# has_female_investor
# No     9598
# Yes    1666
# Name: count, dtype: int64

# %%
# plot the graph
df_cat.has_female_investor.value_counts().plot(kind='bar',color='blue')
plt.title('has_female_investor Count')
plt.xlabel('has_female_investor')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The number of Foundation has female investor is 1666.
#  - The number of Foundation has not female investor is 9598.

# %%
df_cat.columns
# Out:
# Index(['gender', 'education_level', 'alma_mater', 'field_of_study',
#        'is_first_generation', 'industry_sector', 'city', 'state', 'is_unicorn',
#        'has_female_investor', 'mentorship_access', 'policy_support'],
#       dtype='object')

# %% [markdown]
# ### mentorship_access

# %%
# show the counts
df_cat.mentorship_access.value_counts()
# Out:
# mentorship_access
# No     6799
# Yes    4465
# Name: count, dtype: int64

# %%
# plot the graph
df_cat.mentorship_access.value_counts().plot(kind='bar',color='blue')
plt.title('mentorship_access Count')
plt.xlabel('mentorship_access')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The number of employee with mentorship access is 4465.
#  - The number of employee without mentorship access is 6799.

# %%
df_cat.columns
# Out:
# Index(['gender', 'education_level', 'alma_mater', 'field_of_study',
#        'is_first_generation', 'industry_sector', 'city', 'state', 'is_unicorn',
#        'has_female_investor', 'mentorship_access', 'policy_support'],
#       dtype='object')

# %% [markdown]
# ### policy_support

# %%
# show the counts
df_cat.policy_support.value_counts()
# Out:
# policy_support
# No     7949
# Yes    3315
# Name: count, dtype: int64

# %%
# plot the graph
df_cat.policy_support.value_counts().plot(kind='bar',color='blue')
plt.title('policy_support Count')
plt.xlabel('policy_support')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The number of employee has policy support is 3315.
#  - The number of employee has not policy support is 7949.

# %%
df_cat.columns
# Out:
# Index(['gender', 'education_level', 'alma_mater', 'field_of_study',
#        'is_first_generation', 'industry_sector', 'city', 'state', 'is_unicorn',
#        'has_female_investor', 'mentorship_access', 'policy_support'],
#       dtype='object')

# %% [markdown]
# # Bivariate Analysis

# %%
df_num.corr()
# Out:
#                             age  prior_work_experience  funding_amount  \
# age                    1.000000               0.024872        0.007024
# prior_work_experience  0.024872               1.000000       -0.013882
# funding_amount         0.007024              -0.013882        1.000000
# funding_rounds         0.014302              -0.005465        0.400101
# jobs_created           0.006449               0.006948       -0.000726
# investor_count         0.011328              -0.006754        0.413504
# founding_year         -0.008198               0.000990        0.007293
#
#                        funding_rounds  jobs_created  investor_count  \
# age                          0.014302      0.006449        0.011328
# prior_work_experience       -0.005465      0.006948       -0.006754
# funding_amount               0.400101     -0.000726        0.413504
# funding_rounds               1.000000     -0.008880        0.823678
# ...

# %%
# plot the scatter plot between funding rounds and invester count
sns.scatterplot(x="funding_rounds",y="investor_count",data=df_num)
plt.title('Funding round vs Invester count')
plt.xlabel('Funding rounds')
plt.ylabel('Invester count')
plt.grid()
plt.show()

# %% [markdown]
# ### Bivariate analysis on one numerical and one categorical column

# %%
df_cat.columns
# Out:
# Index(['gender', 'education_level', 'alma_mater', 'field_of_study',
#        'is_first_generation', 'industry_sector', 'city', 'state', 'is_unicorn',
#        'has_female_investor', 'mentorship_access', 'policy_support'],
#       dtype='object')

# %%
df_num.columns
# Out:
# Index(['age', 'prior_work_experience', 'funding_amount', 'funding_rounds',
#        'jobs_created', 'investor_count', 'founding_year'],
#       dtype='object')

# %% [raw]
# gender, age
# education_level, age
# alma_mater, age
# field_of_study, age
# is_first_generation, age
# industry_sector, age
# city, age
# state, age
# is_unicorn, age
# has_female_investor, age
# mentorship_access, age
# policy_support, age

# %%
# gender vs age
sns.barplot(x="gender", y="age", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("gender vs age")
plt.xlabel("gender")
plt.ylabel("age")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar age across different gender.
#  - The average age for all gender is (Low, Medium, High) remain around 30, indicating that gender has little no effect on age.

# %%
# education_level vs age
sns.barplot(x="education_level", y="age", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("education_level vs age")
plt.xlabel("education_level")
plt.ylabel("age")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar age across different education level.
#  - The average age for all education level is (Low, Medium, High) remain around 30, indicating that education level has little no effect on age.

# %%
# alma_mater vs age
sns.barplot(x="alma_mater", y="age", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("alma_mater vs age")
plt.xlabel("alma_mater")
plt.ylabel("age")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar age across different alma mater.
#  - The average age for all alma mater is (Low, Medium, High) remain around 30, indicating that alma mater has little no effect on age.

# %%
# field_of_study vs age
sns.barplot(x="field_of_study", y="age", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("field_of_study vs age")
plt.xlabel("field_of_study")
plt.ylabel("age")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar age across different field of study.
#  - The average age for all field of study is (Low, Medium, High) remain around 28, indicating that feild of study has little no effect on age.

# %%
# is_first_generation vs age
sns.barplot(x="is_first_generation", y="age", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("is_first_generation vs age")
plt.xlabel("is_first_generation")
plt.ylabel("age")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar age across its from first generation or not.
#  - The average of its from first generation or not for all gender is (Low, Medium, High) remain around 30, indicating that gender has little no effect on whether he/she is from first generation or not.

# %%
# industry_sector vs age
sns.barplot(x="industry_sector", y="age", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("industry_sector vs age")
plt.xlabel("industry_sector")
plt.ylabel("age")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar age across different industry sector.
#  - The average age for all industry sector is (Low, Medium, High) remain around 30, indicating that industry sector has little no effect on age.

# %%
# city vs age
sns.barplot(x="city", y="age", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("city vs age")
plt.xlabel("city")
plt.ylabel("age")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar age across different city.
#  - The average age for all city is (Low, Medium, High) remain around 30, indicating that city has little no effect on age.

# %%
# state vs age
sns.barplot(x="state", y="age", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("state vs age")
plt.xlabel("state")
plt.ylabel("age")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar age across different state.
#  - The average age for all state is (Low, Medium, High) remain around 30, indicating that state has little no effect on age.

# %%
# is_unicorn vs age
sns.barplot(x="is_unicorn", y="age", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("is_unicorn vs age")
plt.xlabel("is_unicorn")
plt.ylabel("age")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar age startup is unicorn or not.
#  - The average age for startup is unicorn or not is (Low, Medium, High) remain around 30, indicating that startup is unicorn or not has little no effect on age.

# %%
# has_female_investor vs age
sns.barplot(x="has_female_investor", y="age", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("has_female_investor vs age")
plt.xlabel("has_female_investor")
plt.ylabel("age")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar age across foundation has female investor or not.
#  - The average age for foundation has female investor or not is (Low, Medium, High) remain around 30, indicating that foundation has female investor or not has little no effect on age.

# %%
# mentorship_access vs age
sns.barplot(x="mentorship_access", y="age", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("mentorship_access vs age")
plt.xlabel("mentorship_access")
plt.ylabel("age")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar age across employee has mentorship access or not.
#  - The average age for all mentorship acces has or not is (Low, Medium, High) remain around 30, indicating that has mentorship access or not has little no effect on age.

# %%
# policy_support vs age
sns.barplot(x="policy_support", y="age", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("policy_support vs age")
plt.xlabel("policy_support")
plt.ylabel("age")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar age across employee has policy support or not.
#  - The average age for all policy support has or not is (Low, Medium, High) remain around 30, indicating that has policy support or not has little no effect on age.

# %% [raw]
# gender, prior_work_experience
# education_level, prior_work_experience
# alma_mater, prior_work_experience
# field_of_study, prior_work_experience
# is_first_generation, prior_work_experience
# industry_sector, prior_work_experience
# city, prior_work_experience
# state, prior_work_experience
# is_unicorn, prior_work_experience
# has_female_investor, prior_work_experience
# mentorship_access, prior_work_experience
# policy_support, prior_work_experience

# %%
# gender vs prior_work_experience
sns.barplot(x="gender", y="prior_work_experience", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("gender vs prior_work_experience")
plt.xlabel("gender")
plt.ylabel("prior_work_experience")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar prior work experience across different gender.
#  - The average prior work experience for all gender is (Low, Medium, High) remain around 7, indicating that gender has little no effect on prior work experience.

# %%
# education_level vs prior_work_experience
sns.barplot(x="education_level", y="prior_work_experience", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("education_level vs prior_work_experience")
plt.xlabel("education_level")
plt.ylabel("prior_work_experience")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar prior work experience across different education level.
#  - The average prior work experience for all education level is (Low, Medium, High) remain around 7, indicating that education level has little no effect on prior work experience.

# %%
# alma_mater vs prior_work_experience
sns.barplot(x="alma_mater", y="prior_work_experience", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("alma_mater vs prior_work_experience")
plt.xlabel("alma_mater")
plt.ylabel("prior_work_experience")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar prior work experience across different alma mater.
#  - The average prior work experience for all alma mater is (Low, Medium, High) remain around 7, indicating that alma mater has little no effect on prior work experience.

# %%
# field_of_study vs prior_work_experience
sns.barplot(x="field_of_study", y="prior_work_experience", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("field_of_study vs prior_work_experience")
plt.xlabel("field_of_study")
plt.ylabel("prior_work_experience")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar prior work experience across different field of study.
#  - The average prior work experience for all field of study is (Low, Medium, High) remain around 7, indicating that field of study has little no effect on prior work experience.

# %%
# is_first_generation vs prior_work_experience
sns.barplot(x="is_first_generation", y="prior_work_experience", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("is_first_generation vs prior_work_experience")
plt.xlabel("is_first_generation")
plt.ylabel("prior_work_experience")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar prior work experience across is from first generation or not.
#  - The average prior work experience for all from first generation or not is (Low, Medium, High) remain around 7, indicating that is from first generation or not has little no effect on prior work experience.

# %%
# industry_sector vs prior_work_experience
sns.barplot(x="industry_sector", y="prior_work_experience", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("industry_sector vs prior_work_experience")
plt.xlabel("industry_sector")
plt.ylabel("prior_work_experience")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar prior work experience across different industry sector.
#  - The average prior work experience for all industry sector is (Low, Medium, High) remain around 7, indicating that industry sector has little no effect on prior work experience.

# %%
# city vs prior_work_experience
sns.barplot(x="city", y="prior_work_experience", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("city vs prior_work_experience")
plt.xlabel("city")
plt.ylabel("prior_work_experience")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar prior work experience across different city.
#  - The average prior work experience for all city is (Low, Medium, High) remain around 7, indicating that city has little no effect on prior work experience.

# %%
# state vs prior_work_experience
sns.barplot(x="state", y="prior_work_experience", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("state vs prior_work_experience")
plt.xlabel("state")
plt.ylabel("prior_work_experience")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar prior work experience across different state.
#  - The average prior work experience for all satte is (Low, Medium, High) remain around 7, indicating that state has little no effect on prior work experience.

# %%
# is_unicorn vs prior_work_experience
sns.barplot(x="is_unicorn", y="prior_work_experience", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("is_unicorn vs prior_work_experience")
plt.xlabel("is_unicorn")
plt.ylabel("prior_work_experience")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar prior work experience across different is unicorn or not.
#  - The average prior work experience for all is unicorn or not is (Low, Medium, High) remain around 7, indicating that is unicorn or not has little no effect on prior work experience.

# %%
# has_female_investor vs prior_work_experience
sns.barplot(x="has_female_investor", y="prior_work_experience", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("has_female_investor vs prior_work_experience")
plt.xlabel("has_female_investor")
plt.ylabel("prior_work_experience")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar prior work experience across different has female investor or not.
#  - The average prior work experience for all has female investor or not is (Low, Medium, High) remain around 7, indicating that has female investor or not has little no effect on prior work experience.

# %%
# mentorship_access vs prior_work_experience
sns.barplot(x="mentorship_access", y="prior_work_experience", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("mentorship_access vs prior_work_experience")
plt.xlabel("mentorship_access")
plt.ylabel("prior_work_experience")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar prior work experience across different has mentorship access or not.
#  - The average prior work experience for all has mentorship access or not is (Low, Medium, High) remain around 7, indicating that has mentorship access or not has little no effect on prior work experience.

# %%
# policy_support vs prior_work_experience
sns.barplot(x="policy_support", y="prior_work_experience", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("policy_support vs prior_work_experience")
plt.xlabel("policy_support")
plt.ylabel("prior_work_experience")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar prior work experience across different has policy support or not.
#  - The average prior work experience for all has policy support or not is (Low, Medium, High) remain around 7, indicating that policy support has little no effect on prior work experience.

# %%
df_num.columns
# Out:
# Index(['age', 'prior_work_experience', 'funding_amount', 'funding_rounds',
#        'jobs_created', 'investor_count', 'founding_year'],
#       dtype='object')

# %% [raw]
# gender, funding_amount
# education_level, funding_amount
# alma_mater, funding_amount
# field_of_study, funding_amount
# is_first_generation, funding_amount
# industry_sector, funding_amount
# city, funding_amount
# state, funding_amount
# is_unicorn, funding_amount
# has_female_investor, funding_amount
# mentorship_access, funding_amount
# policy_support, funding_amount

# %%
# gender vs funding_amount
sns.barplot(x="gender", y="funding_amount", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("gender vs funding_amount")
plt.xlabel("gender")
plt.ylabel("funding_amount")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar funding amount across different gender.
#  - The average funding amount for all gender is (Low, Medium, High) remain around 2, indicating that gender has little no effect on funding amount.

# %%
# education_level vs funding_amount
sns.barplot(x="education_level", y="funding_amount", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("education_level vs funding_amount")
plt.xlabel("education_level")
plt.ylabel("funding_amount")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar funding amount across different education level.
#  - The average funding amount for all education level is (Low, Medium, High) remain around 2, indicating that education level has little no effect on funding amount.

# %%
# alma_mater vs funding_amount
sns.barplot(x="alma_mater", y="funding_amount", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("alma_mater vs funding_amount")
plt.xlabel("alma_mater")
plt.ylabel("funding_amount")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar funding amount across different alma mater.
#  - The average funding amount for all alma mater is (Low, Medium, High) remain around 2, indicating that alma mater has little no effect on funding amount.

# %%
# field_of_study vs funding_amount
sns.barplot(x="field_of_study", y="funding_amount", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("field_of_study vs funding_amount")
plt.xlabel("field_of_study")
plt.ylabel("funding_amount")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar funding amount across different field of study.
#  - The average funding amount for all field of study is (Low, Medium, High) remain around 2, indicating that field of study has little no effect on funding amount.

# %%
# is_first_generation vs funding_amount
sns.barplot(x="is_first_generation", y="funding_amount", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("is_first_generation vs funding_amount")
plt.xlabel("is_first_generation")
plt.ylabel("funding_amount")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar funding amount across different generation.
#  - The average funding amount for all generation is (Low, Medium, High) remain around 2, indicating that generation has little no effect on funding amount.

# %%
# industry_sector vs funding_amount
sns.barplot(x="industry_sector", y="funding_amount", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("industry_sector vs funding_amount")
plt.xlabel("industry_sector")
plt.ylabel("funding_amount")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar funding amount across different industry sector.
#  - The average funding amount for all industry sector is (Low, Medium, High) remain around 2, indicating that industry sector has little no effect on funding amount.

# %%
# city vs funding_amount
sns.barplot(x="city", y="funding_amount", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("city vs funding_amount")
plt.xlabel("city")
plt.ylabel("funding_amount")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar funding amount across different city.
#  - The average funding amount for all city is (Low, Medium, High) remain around 2, indicating that city has little no effect on funding amount.

# %%
# state vs funding_amount
sns.barplot(x="state", y="funding_amount", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("state vs funding_amount")
plt.xlabel("state")
plt.ylabel("funding_amount")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar funding amount across different state.
#  - The average funding amount for all state is (Low, Medium, High) remain around 2, indicating that state has little no effect on funding amount.

# %%
# is_unicorn vs funding_amount
sns.barplot(x="is_unicorn", y="funding_amount", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("is_unicorn vs funding_amount")
plt.xlabel("is_unicorn")
plt.ylabel("funding_amount")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar funding amount across different is unicorn or not.
#  - The average funding amount for all is unicorn or not is (Low, Medium, High) remain around 2, indicating that unicorn o0r not has little no effect on funding amount.

# %%
# has_female_investor vs funding_amount
sns.barplot(x="has_female_investor", y="funding_amount", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("has_female_investor vs funding_amount")
plt.xlabel("has_female_investor")
plt.ylabel("funding_amount")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar funding amount across presence of female investor.
#  - The average funding amount for presence of female investor is (Low, Medium, High) remain around 2, indicating that female investor has little no effect on funding amount.

# %%
# mentorship_access vs funding_amount
sns.barplot(x="mentorship_access", y="funding_amount", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("mentorship_access vs funding_amount")
plt.xlabel("mentorship_access")
plt.ylabel("funding_amount")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar funding amount across different mentorship accesss.
#  - The average funding amount for all mentorship access is (Low, Medium, High) remain around 2, indicating that mentorship acces has little no effect on funding amount.

# %%
# policy_support vs funding_amount
sns.barplot(x="policy_support", y="funding_amount", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("policy_support vs funding_amount")
plt.xlabel("policy_support")
plt.ylabel("funding_amount")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar funding amount across different policy support.
#  - The average funding amount for all policy support is (Low, Medium, High) remain around 2, indicating that policy support has little no effect on funding amount.

# %%
df_num.columns
# Out:
# Index(['age', 'prior_work_experience', 'funding_amount', 'funding_rounds',
#        'jobs_created', 'investor_count', 'founding_year'],
#       dtype='object')

# %% [raw]
# gender, funding_rounds
# education_level, funding_rounds
# alma_mater, funding_rounds
# field_of_study, funding_rounds
# is_first_generation, funding_rounds
# industry_sector, funding_rounds
# city, funding_rounds
# state, funding_rounds
# is_unicorn, funding_rounds
# has_female_investor, funding_rounds
# mentorship_access, funding_rounds
# policy_support, funding_rounds

# %%
# gender vs funding_rounds
sns.barplot(x="gender", y="funding_rounds", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("gender vs funding_rounds")
plt.xlabel("gender")
plt.ylabel("funding_rounds")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar funding rounds across different gender.
#  - The average funding rounds for all gender is (Low, Medium, High) remain around 4, indicating that gender has little no effect on funding round.

# %%
# education_level vs funding_rounds
sns.barplot(x="education_level", y="funding_rounds", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("education_level vs funding_rounds")
plt.xlabel("education_level")
plt.ylabel("funding_rounds")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar funding rounds across different education level.
#  - The average funding rounds for all education level is (Low, Medium, High) remain around 4, indicating that education level has little no effect on funding round.

# %%
# alma_mater vs funding_rounds
sns.barplot(x="alma_mater", y="funding_rounds", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("alma_mater vs funding_rounds")
plt.xlabel("alma_mater")
plt.ylabel("funding_rounds")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar funding rounds across different alma mater.
#  - The average funding rounds for all alma mater is (Low, Medium, High) remain around 4, indicating that alma mater has little no effect on funding round.

# %%
# field_of_study vs funding_rounds
sns.barplot(x="field_of_study", y="funding_rounds", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("field_of_study vs funding_rounds")
plt.xlabel("field_of_study")
plt.ylabel("funding_rounds")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar funding rounds across different field of study.
#  - The average funding rounds for all field of study is (Low, Medium, High) remain around 4, indicating that feild of study has little no effect on funding round.

# %%
# is_first_generation vs funding_rounds
sns.barplot(x="is_first_generation", y="funding_rounds", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("is_first_generation vs funding_rounds")
plt.xlabel("is_first_generation")
plt.ylabel("funding_rounds")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar funding rounds across different generation.
#  - The average funding rounds for all generation is (Low, Medium, High) remain around 4, indicating that generation has little no effect on funding round.

# %%
# industry_sector vs funding_rounds
sns.barplot(x="industry_sector", y="funding_rounds", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("industry_sector vs funding_rounds")
plt.xlabel("industry_sector")
plt.ylabel("funding_rounds")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar funding rounds across different industry sector.
#  - The average funding rounds for all industry sector is (Low, Medium, High) remain around 4, indicating that industry sector has little no effect on funding round.

# %%
# city vs funding_rounds
sns.barplot(x="city", y="funding_rounds", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("city vs funding_rounds")
plt.xlabel("city")
plt.ylabel("funding_rounds")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar funding rounds across different city.
#  - The average funding rounds for all city is (Low, Medium, High) remain around 4, indicating that city has little no effect on funding round.

# %%
# state vs funding_rounds
sns.barplot(x="state", y="funding_rounds", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("state vs funding_rounds")
plt.xlabel("state")
plt.ylabel("funding_rounds")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar funding rounds across different state.
#  - The average funding rounds for all state is (Low, Medium, High) remain around 4, indicating that state has little no effect on funding round.

# %%
# is_unicorn vs funding_rounds
sns.barplot(x="is_unicorn", y="funding_rounds", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("is_unicorn vs funding_rounds")
plt.xlabel("is_unicorn")
plt.ylabel("funding_rounds")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar funding rounds across is unicorn or not.
#  - The average funding rounds for is unicorn or not is (Low, Medium, High) remain around 4, indicating that unicorn has little no effect on funding round.

# %%
# has_female_investor vs funding_rounds
sns.barplot(x="has_female_investor", y="funding_rounds", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("has_female_investor vs funding_rounds")
plt.xlabel("has_female_investor")
plt.ylabel("funding_rounds")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar funding rounds across presence of female investor.
#  - The average funding rounds for presence of female investor is (Low, Medium, High) remain around 4, indicating that female investor has little no effect on funding round.

# %%
# mentorship_access vs funding_rounds
sns.barplot(x="mentorship_access", y="funding_rounds", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("mentorship_access vs funding_rounds")
plt.xlabel("mentorship_access")
plt.ylabel("funding_rounds")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar funding rounds across different mentorship access.
#  - The average funding rounds for all mentorship access is (Low, Medium, High) remain around 4, indicating that mentorship access has little no effect on funding round.

# %%
# policy_support vs funding_rounds
sns.barplot(x="policy_support", y="funding_rounds", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("policy_support vs funding_rounds")
plt.xlabel("policy_support")
plt.ylabel("funding_rounds")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar funding rounds across different policy support.
#  - The average funding rounds for all policy support is (Low, Medium, High) remain around 4, indicating that policy support has little no effect on funding round.

# %%
df_num.columns
# Out:
# Index(['age', 'prior_work_experience', 'funding_amount', 'funding_rounds',
#        'jobs_created', 'investor_count', 'founding_year'],
#       dtype='object')

# %% [raw]
# gender, jobs_created
# education_level, jobs_created
# alma_mater, jobs_created
# field_of_study, jobs_created
# is_first_generation, jobs_created
# industry_sector, jobs_created
# city, jobs_created
# state, jobs_created
# is_unicorn, jobs_created
# has_female_investor, jobs_created
# mentorship_access, jobs_created
# policy_support, jobs_created

# %%
# gender vs jobs_created
sns.barplot(x="gender", y="jobs_created", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("gender vs jobs_created")
plt.xlabel("gender")
plt.ylabel("jobs_created")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
# education_level vs jobs_created
sns.barplot(x="education_level", y="jobs_created", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("education_level vs jobs_created")
plt.xlabel("education_level")
plt.ylabel("jobs_created")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
# alma_mater vs jobs_created
sns.barplot(x="alma_mater", y="jobs_created", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("alma_mater vs jobs_created")
plt.xlabel("alma_mater")
plt.ylabel("jobs_created")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
# field_of_study vs jobs_created
sns.barplot(x="field_of_study", y="jobs_created", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("field_of_study vs jobs_created")
plt.xlabel("field_of_study")
plt.ylabel("jobs_created")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
# is_first_generation vs jobs_created
sns.barplot(x="is_first_generation", y="jobs_created", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("is_first_generation vs jobs_created")
plt.xlabel("is_first_generation")
plt.ylabel("jobs_created")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
# industry_sector vs jobs_created
sns.barplot(x="industry_sector", y="jobs_created", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("industry_sector vs jobs_created")
plt.xlabel("industry_sector")
plt.ylabel("jobs_created")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
# city vs jobs_created
sns.barplot(x="city", y="jobs_created", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("city vs jobs_created")
plt.xlabel("city")
plt.ylabel("jobs_created")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
# state vs jobs_created
sns.barplot(x="state", y="jobs_created", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("state vs jobs_created")
plt.xlabel("state")
plt.ylabel("jobs_created")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
# is_unicorn vs jobs_created
sns.barplot(x="is_unicorn", y="jobs_created", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("is_unicorn vs jobs_created")
plt.xlabel("is_unicorn")
plt.ylabel("jobs_created")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
# has_female_investor vs jobs_created
sns.barplot(x="has_female_investor", y="jobs_created", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("has_female_investor vs jobs_created")
plt.xlabel("has_female_investor")
plt.ylabel("jobs_created")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
# mentorship_access vs jobs_created
sns.barplot(x="mentorship_access", y="jobs_created", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("mentorship_access vs jobs_created")
plt.xlabel("mentorship_access")
plt.ylabel("jobs_created")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
# policy_support vs jobs_created
sns.barplot(x="policy_support", y="jobs_created", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("policy_support vs jobs_created")
plt.xlabel("policy_support")
plt.ylabel("jobs_created")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
df_num.columns
# Out:
# Index(['age', 'prior_work_experience', 'funding_amount', 'funding_rounds',
#        'jobs_created', 'investor_count', 'founding_year'],
#       dtype='object')

# %% [raw]
# gender, investor_count
# education_level, investor_count
# alma_mater, investor_count
# field_of_study, investor_count
# is_first_generation, investor_count
# industry_sector, investor_count
# city, investor_count
# state, investor_count
# is_unicorn, investor_count
# has_female_investor, investor_count
# mentorship_access, investor_count
# policy_support, investor_count

# %%
# gender vs investor_count
sns.barplot(x="gender", y="investor_count", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("gender vs investor_count")
plt.xlabel("gender")
plt.ylabel("investor_count")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar investor count across different gender.
#  - The average investor count for all gender is (Low, Medium, High) remain around 14, indicating that gender has little no effect on investor count.

# %%
# education_level vs investor_count
sns.barplot(x="education_level", y="investor_count", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("education_level vs investor_count")
plt.xlabel("education_level")
plt.ylabel("investor_count")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar investor count across different education level.
#  - The average investor count for all education level is (Low, Medium, High) remain around 14, indicating that education level has little no effect on investor count.

# %%
# alma_mater vs investor_count
sns.barplot(x="alma_mater", y="investor_count", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("alma_mater vs investor_count")
plt.xlabel("alma_mater")
plt.ylabel("investor_count")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar investor count across different alma mater.
#  - The average investor count for all alma mater is (Low, Medium, High) remain around 14, indicating that alma mater has little no effect on investor count.

# %%
# field_of_study vs investor_count
sns.barplot(x="field_of_study", y="investor_count", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("field_of_study vs investor_count")
plt.xlabel("field_of_study")
plt.ylabel("investor_count")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar investor count across different field of study.
#  - The average investor count for all field of study is (Low, Medium, High) remain around 14, indicating that field of study has little no effect on investor count.

# %%
# is_first_generation vs investor_count
sns.barplot(x="is_first_generation", y="investor_count", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("is_first_generation vs investor_count")
plt.xlabel("is_first_generation")
plt.ylabel("investor_count")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar investor count across different generation.
#  - The average investor count for all generation is (Low, Medium, High) remain around 14, indicating that generation has little no effect on investor count.

# %%
# industry_sector vs investor_count
sns.barplot(x="industry_sector", y="investor_count", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("industry_sector vs investor_count")
plt.xlabel("industry_sector")
plt.ylabel("investor_count")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar investor count across different industry sector.
#  - The average investor count for all industry sector is (Low, Medium, High) remain around 14, indicating that industry sector has little no effect on investor count.

# %%
# city vs investor_count
sns.barplot(x="city", y="investor_count", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("city vs investor_count")
plt.xlabel("city")
plt.ylabel("investor_count")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar investor count across different city.
#  - The average investor count for all city is (Low, Medium, High) remain around 14, indicating that city has little no effect on investor count.

# %%
# state vs investor_count
sns.barplot(x="state", y="investor_count", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("state vs investor_count")
plt.xlabel("state")
plt.ylabel("investor_count")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar investor count across different state.
#  - The average investor count for all state is (Low, Medium, High) remain around 14, indicating that state has little no effect on investor count.

# %%
# is_unicorn vs investor_count
sns.barplot(x="is_unicorn", y="investor_count", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("is_unicorn vs investor_count")
plt.xlabel("is_unicorn")
plt.ylabel("investor_count")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
# has_female_investor vs investor_count
sns.barplot(x="has_female_investor", y="investor_count", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("has_female_investor vs investor_count")
plt.xlabel("has_female_investor")
plt.ylabel("investor_count")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar investor count across persence of female investor.
#  - The average investor count for presence of female investor is (Low, Medium, High) remain around 14, indicating that female investor has little no effect on investor count.

# %%
# mentorship_access vs investor_count
sns.barplot(x="mentorship_access", y="investor_count", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("mentorship_access vs investor_count")
plt.xlabel("mentorship_access")
plt.ylabel("investor_count")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar investor count across different mentorship access.
#  - The average investor count for all mentorship access is (Low, Medium, High) remain around 14, indicating that mentorship access has little no effect on investor count.

# %%
# policy_support vs investor_count
sns.barplot(x="policy_support", y="investor_count", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("policy_support vs investor_count")
plt.xlabel("policy_support")
plt.ylabel("investor_count")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar investor count across different policy support.
#  - The average investor count for all policy support is (Low, Medium, High) remain around 14, indicating that policy support has little no effect on investor count.

# %%
df_num.columns
# Out:
# Index(['age', 'prior_work_experience', 'funding_amount', 'funding_rounds',
#        'jobs_created', 'investor_count', 'founding_year'],
#       dtype='object')

# %% [raw]
# gender, founding_year
# education_level, founding_year
# alma_mater, founding_year
# field_of_study, founding_year
# is_first_generation, founding_year
# industry_sector, founding_year
# city, founding_year
# state, founding_year
# is_unicorn, founding_year
# has_female_investor, founding_year
# mentorship_access, founding_year
# policy_support, founding_year

# %%
# gender vs founding_year
sns.barplot(x="gender", y="founding_year", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("gender vs founding_year")
plt.xlabel("gender")
plt.ylabel("founding_year")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar founding year across different gender.
#  - The average founding year for all gender is (Low, Medium, High) remain around 2000, indicating that gender has little no effect on founding year.

# %%
# education_level vs founding_year
sns.barplot(x="education_level", y="founding_year", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("education_level vs founding_year")
plt.xlabel("education_level")
plt.ylabel("founding_year")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar founding year across different education level.
#  - The average founding year for all education level is (Low, Medium, High) remain around 2000, indicating that education level has little no effect on founding year.

# %%
# alma_mater vs founding_year
sns.barplot(x="alma_mater", y="founding_year", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("alma_mater vs founding_year")
plt.xlabel("alma_mater")
plt.ylabel("founding_year")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar founding year across different alma mater.
#  - The average founding year for all alma mater is (Low, Medium, High) remain around 2000, indicating that alma mater has little no effect on founding year.

# %%
# field_of_study vs founding_year
sns.barplot(x="field_of_study", y="founding_year", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("field_of_study vs founding_year")
plt.xlabel("field_of_study")
plt.ylabel("founding_year")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar founding year across different field of study.
#  - The average founding year for all field of study is (Low, Medium, High) remain around 2000, indicating that field of study has little no effect on founding year.

# %%
# is_first_generation vs founding_year
sns.barplot(x="is_first_generation", y="founding_year", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("is_first_generation vs founding_year")
plt.xlabel("is_first_generation")
plt.ylabel("founding_year")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar founding year across different generation.
#  - The average founding year for all generation is (Low, Medium, High) remain around 2000, indicating that generation has little no effect on founding year.

# %%
# industry_sector vs founding_year
sns.barplot(x="industry_sector", y="founding_year", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("industry_sector vs founding_year")
plt.xlabel("industry_sector")
plt.ylabel("founding_year")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar founding year across different industry sector.
#  - The average founding year for all industry sector is (Low, Medium, High) remain around 2000, indicating that industry sector has little no effect on founding year.

# %%
# city vs founding_year
sns.barplot(x="city", y="founding_year", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("city vs founding_year")
plt.xlabel("city")
plt.ylabel("founding_year")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar founding year across different city.
#  - The average founding year for all city is (Low, Medium, High) remain around 2000, indicating that city has little no effect on founding year.

# %%
# state vs founding_year
sns.barplot(x="state", y="founding_year", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("state vs founding_year")
plt.xlabel("state")
plt.ylabel("founding_year")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar founding year across different state.
#  - The average founding year for all state is (Low, Medium, High) remain around 2000, indicating that state has little no effect on founding year.

# %%
# is_unicorn vs founding_year
sns.barplot(x="is_unicorn", y="founding_year", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("is_unicorn vs founding_year")
plt.xlabel("is_unicorn")
plt.ylabel("founding_year")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar founding year across is unicorn or not.
#  - The average founding year for all is unicorn or not is (Low, Medium, High) remain around 2000, indicating that unicorn has little no effect on founding year.

# %%
# has_female_investor vs founding_year
sns.barplot(x="has_female_investor", y="founding_year", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("has_female_investor vs founding_year")
plt.xlabel("has_female_investor")
plt.ylabel("founding_year")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar founding year across presence of female investor.
#  - The average founding year for presence of female investor is (Low, Medium, High) remain around 2000, indicating that female investor has little no effect on founding year.

# %%
# mentorship_access vs founding_year
sns.barplot(x="mentorship_access", y="founding_year", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("mentorship_access vs founding_year")
plt.xlabel("mentorship_access")
plt.ylabel("founding_year")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar founding year across different mentorship access.
#  - The average founding year for all mentorship access is (Low, Medium, High) remain around 2000, indicating that mentorship access has little no effect on founding year.

# %%
# policy_support vs founding_year
sns.barplot(x="policy_support", y="founding_year", data=df_indian_startup_founders_dataset, color='#80B3FF', estimator='mean')
plt.title("policy_support vs founding_year")
plt.xlabel("policy_support")
plt.ylabel("founding_year")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced as we observed similar founding year across different policy support.
#  - The average founding year for all policy support is (Low, Medium, High) remain around 2000, indicating that policy support has little no effect on founding year.

# %% [markdown]
# ### Decide the target variable

# %%
df_indian_startup_founders_dataset.head()
# Out:
#   founder_id             gender  age education_level   alma_mater  \
# 0     F00002  Prefer not to say   22      Bachelor’s        Other
# 1     F00003  Prefer not to say   28     High School        Other
# 2     F00004               Male   23        Master’s        Other
# 3     F00005               Male   28      Bachelor’s  IIT Roorkee
# 4     F00006               Male   29      Bachelor’s        Other
#
#      field_of_study  prior_work_experience is_first_generation startup_id  \
# 0       Engineering                     13                 Yes     S08268
# 1          Business                      1                 Yes     S07952
# 2  Computer Science                      5                 Yes     S00991
# 3          Business                     18                 Yes     S07446
# 4             Other                      2                 Yes     S03544
#
#   industry_sector  ...        state funding_amount  funding_rounds  \
# ...

# %%
# let set the target variable to be jobs created
target=df_indian_startup_founders_dataset.jobs_created

df_indian_startup_founders_dataset=df_indian_startup_founders_dataset.drop('jobs_created',axis=1)

# %%
df_indian_startup_founders_dataset.columns
# Out:
# Index(['founder_id', 'gender', 'age', 'education_level', 'alma_mater',
#        'field_of_study', 'prior_work_experience', 'is_first_generation',
#        'startup_id', 'industry_sector', 'city', 'state', 'funding_amount',
#        'funding_rounds', 'is_unicorn', 'investor_count', 'has_female_investor',
#        'founding_year', 'mentorship_access', 'policy_support'],
#       dtype='object')

# %% [markdown]
# ## Prepare the data for ML

# %% [markdown]
# ### Perform encoding on categorical data

# %%
df_cat
# Out:
#                   gender education_level   alma_mater    field_of_study  \
# 0      Prefer not to say      Bachelor’s        Other       Engineering
# 1      Prefer not to say     High School        Other          Business
# 2                   Male        Master’s        Other  Computer Science
# 3                   Male      Bachelor’s  IIT Roorkee          Business
# 4                   Male      Bachelor’s        Other             Other
# ...                  ...             ...          ...               ...
# 11259  Prefer not to say        Master’s        Other             Other
# 11260             Female             PhD        Other          Business
# 11261               Male        Master’s        Other  Computer Science
# 11262  Prefer not to say      Bachelor’s    IIT Delhi  Computer Science
# 11263  Prefer not to say      Bachelor’s        Other       Engineering
#
#       is_first_generation     industry_sector       city        state  \
# ...

# %%
df_encoded=pd.get_dummies(df_cat)

# %%
df_encoded
# Out:
#        gender_Female  gender_Male  gender_Non-binary  \
# 0              False        False              False
# 1              False        False              False
# 2              False         True              False
# 3              False         True              False
# 4              False         True              False
# ...              ...          ...                ...
# 11259          False        False              False
# 11260           True        False              False
# 11261          False         True              False
# 11262          False        False              False
# 11263          False        False              False
#
#        gender_Prefer not to say  education_level_Bachelor’s  \
# 0                          True                        True
# 1                          True                       False
# 2                         False                       False
# 3                         False                        True
# ...

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11264 entries, 0 to 11263
# Data columns (total 42 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   gender_Female                       11264 non-null  bool
#  1   gender_Male                         11264 non-null  bool
#  2   gender_Non-binary                   11264 non-null  bool
#  3   gender_Prefer not to say            11264 non-null  bool
#  4   education_level_Bachelor’s          11264 non-null  bool
#  5   education_level_High School         11264 non-null  bool
#  6   education_level_Master’s            11264 non-null  bool
#  7   education_level_Other               11264 non-null  bool
#  8   education_level_PhD                 11264 non-null  bool
#  9   alma_mater_BITS Pilani              11264 non-null  bool
#  10  alma_mater_IIT Delhi                11264 non-null  bool
# ...

# %% [markdown]
# ### scale the numerical columns

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()

# %%
scale=ss.fit_transform(df_num)
scale
# Out:
# array([[-0.83255662,  0.71630507, -0.28764991, ..., -0.34176751,
#         -0.04589455,  0.27929058],
#        [-0.08084985, -0.74193825, -0.33699866, ..., -0.04108028,
#         -1.10368272,  0.56489467],
#        [-0.70727216, -0.25585714, -0.20105326, ..., -0.3602881 ,
#         -0.49923234,  0.85049876],
#        ...,
#        [-0.45670324, -0.74193825, -0.23753109, ..., -0.35266197,
#         -0.12145085,  1.13610286],
#        [-0.70727216,  0.95934562,  1.79888683, ..., -0.38316647,
#          1.616344  , -0.00631351],
#        [ 0.04443461,  1.68846728,  0.7109273 , ..., -0.21757061,
#          2.52301958,  0.13648853]])

# %%
df_scaled=pd.DataFrame(scale,columns=df_num.columns)

# %%
df_scaled.shape
# Out:
# (11264, 7)

# %%
df_scaled
# Out:
#             age  prior_work_experience  funding_amount  funding_rounds  \
# 0     -0.832557               0.716305       -0.287650        0.242775
# 1     -0.080850              -0.741938       -0.336999       -1.513791
# 2     -0.707272              -0.255857       -0.201053       -0.108538
# 3     -0.080850               1.323906       -0.331404       -0.811164
# 4      0.044435              -0.620418       -0.341366       -1.513791
# ...         ...                    ...             ...             ...
# 11259  2.048986              -0.255857        0.252125        1.999342
# 11260 -0.832557              -0.255857       -0.212719       -0.459851
# 11261 -0.456703              -0.741938       -0.237531       -0.459851
# 11262 -0.707272               0.959346        1.798887        1.648028
# 11263  0.044435               1.688467        0.710927        0.594089
#
#        jobs_created  investor_count  founding_year
# 0         -0.341768       -0.045895       0.279291
# ...

# %% [markdown]
# ### Concatenate both the encoded and scaled dataframe

# %%
df_encoded.shape
# Out:
# (11264, 42)

# %%
df_scaled.shape
# Out:
# (11264, 7)

# %%
X=pd.concat([df_encoded,df_scaled],axis=1)
X
# Out:
#        gender_Female  gender_Male  gender_Non-binary  \
# 0              False        False              False
# 1              False        False              False
# 2              False         True              False
# 3              False         True              False
# 4              False         True              False
# ...              ...          ...                ...
# 11259          False        False              False
# 11260           True        False              False
# 11261          False         True              False
# 11262          False        False              False
# 11263          False        False              False
#
#        gender_Prefer not to say  education_level_Bachelor’s  \
# 0                          True                        True
# 1                          True                       False
# 2                         False                       False
# 3                         False                        True
# ...

# %% [markdown]
# ## Now split the data in training and testing set

# %%
from sklearn.model_selection import train_test_split

# %%
X.shape
# Out:
# (11264, 49)

# %%
target.shape
# Out:
# (11264,)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,target,test_size=0.2,random_state=42)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (9011, 49)
# (9011,)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (2253, 49)
# (2253,)

# %% [markdown]
# ## Find the base ML algorithm

# %% [markdown]
# ### Linear Regression

# %%
# Import linear regression algorithm and evaluation matrix
from sklearn.linear_model import LinearRegression

# here we are using MSE as evaluation matrix
from sklearn.metrics import mean_squared_error

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions=model.predict(X_test)

# %%
mse=mean_squared_error(y_test,predictions)
print(f"mean_squared_error = {mse}")
# Out:
# mean_squared_error = 3.470161410804498e-24

# %% [markdown]
# ### Ridge Model

# %%
from sklearn.linear_model import Ridge


# Assuming X_train, X_test, y_train, y_test are already defined from train_test_split

# Create a Ridge regression model
ridge_model = Ridge(alpha=1.0)  # alpha is the regularization strength

# Fit the model to the training data
ridge_model.fit(X_train, y_train)

# Predict on the testing data
predictions = ridge_model.predict(X_test)

# Calculate mean squared error
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error:",mse)
# Out:
# Mean Squared Error: 0.010369008613133687

# %% [markdown]
# ### Lasso Model

# %%
from sklearn.linear_model import Lasso

# Assuming X_train, X_test, y_train, y_test are already defined from train_test_split

# Create a Lasso regression model
lasso_model = Lasso(alpha=1.0)  # alpha is the regularization strength

# Fit the model to the training data
lasso_model.fit(X_train, y_train)

# Predict on the testing data
predictions = lasso_model.predict(X_test)

# Calculate mean squared error
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error:",mse)
# Out:
# Mean Squared Error: 0.9939735595858766

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor


# Assuming X_train, X_test, y_train, y_test are already defined from train_test_split

# Create a Decision Tree regression model
tree_model = DecisionTreeRegressor()

# Fit the model to the training data
tree_model.fit(X_train, y_train)

# Predict on the testing data
predictions = tree_model.predict(X_test)

# Calculate mean squared error
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error:",mse)
# Out:
# Mean Squared Error: 10.410563692853973

# %% [markdown]
# ### Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor


# Assuming X_train, X_test, y_train, y_test are already defined from train_test_split

# Create a Random Forest regression model
forest_model = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the model to the training data
forest_model.fit(X_train, y_train)

# Predict on the testing data
predictions = forest_model.predict(X_test)

# Calculate mean squared error
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error:",mse)
# Out:
# Mean Squared Error: 3.535467998224595

# %% [markdown]
# ### SVR

# %%
from sklearn.svm import SVR


# Assuming X_train, X_test, y_train, y_test are already defined from train_test_split

# Create a SVM regression model
svm_model = SVR(kernel='rbf')  # 'rbf' kernel is commonly used for non-linear regression

# Fit the model to the training data
svm_model.fit(X_train, y_train)

# Predict on the testing data
predictions = svm_model.predict(X_test)

# Calculate mean squared error
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error:",mse)
# Out:
# Mean Squared Error: 830872.8942756433

# %% [markdown]
# **Interpretation**
# As per this method i can conclude that linear regression is our base algorithm because it had the least MSE as compared to others.

# %% [markdown]
# ## Hyper parameter tuning using cross validation

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import mean_squared_error, make_scorer
from sklearn.preprocessing import StandardScaler

# Assuming you already have your dataset as X (features) and y (target)
# X = df.drop(columns=["target"])
# y = df["target"]

# Standardize features (optional but useful if variables are on different scales)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Define model
model = LinearRegression()

# Define K-Fold CV
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# Define scorer for MSE
mse_scorer = make_scorer(mean_squared_error, greater_is_better=False)

# Perform cross-validation
mse_scores = cross_val_score(model, X_scaled, target, scoring=mse_scorer, cv=kf)

# Report results
print("Cross-validated MSE scores:", -mse_scores)  # Negate to show positive MSE
print("Average MSE:", -np.mean(mse_scores))
# Out:
# Cross-validated MSE scores: [1.37805459e-24 3.86928099e-24 3.01034258e-24 2.40216330e-24
#  5.75212510e-24]
# Average MSE: 3.282393312451851e-24
